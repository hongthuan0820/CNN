# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import datasets
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, ZeroPadding2D, BatchNormalization
from tensorflow.keras.optimizers import RMSprop, Adam, SGD, Optimizer
from keras.callbacks import EarlyStopping
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array

# %%
(x_train,y_train),(x_test,y_test) = datasets.cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 11s 0us/step
# 169017344/169001437 [==============================] - 11s 0us/step

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train/=255.0
x_test/=255.0
y_train = np_utils.to_categorical(y_train,100)
y_test = np_utils.to_categorical(y_test,100)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same', input_shape=(32,32,3)))
model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=1))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=1))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(BatchNormalization(axis=1))
model.add(MaxPooling2D((2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(512, activation = 'relu'))
model.add(BatchNormalization(axis=1))
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(BatchNormalization(axis=1))
model.add(Dropout(0.5))
model.add(Dense(100,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_10 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_10 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_11 (Bat  (None, 16, 16, 64)       64
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_11 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_12 (Bat  (None, 8, 8, 128)        32
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_12 (Dropout)        (None, 4, 4, 128)         0
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 512)               1049088
#
#  batch_normalization_13 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  batch_normalization_14 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  dense_8 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 1,311,908
# Trainable params: 1,310,260
# Non-trainable params: 1,648
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit(x_train,y_train,batch_size = 128, epochs = 100,verbose = 1, validation_data =(x_test,y_test))
# Out:
# Epoch 1/50
# 391/391 [==============================] - 15s 35ms/step - loss: 1.5886 - accuracy: 0.5513 - val_loss: 1.5814 - val_accuracy: 0.5603
# Epoch 2/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.5917 - accuracy: 0.5499 - val_loss: 1.6369 - val_accuracy: 0.5546
# Epoch 3/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.5706 - accuracy: 0.5559 - val_loss: 1.5938 - val_accuracy: 0.5594
# Epoch 4/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.5740 - accuracy: 0.5555 - val_loss: 1.5992 - val_accuracy: 0.5558
# Epoch 5/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.5666 - accuracy: 0.5563 - val_loss: 1.6740 - val_accuracy: 0.5424
# Epoch 6/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.5599 - accuracy: 0.5565 - val_loss: 1.5581 - val_accuracy: 0.5687
# Epoch 7/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.5566 - accuracy: 0.5574 - val_loss: 1.5883 - val_accuracy: 0.5648
# Epoch 8/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.5451 - accuracy: 0.5625 - val_loss: 1.5988 - val_accuracy: 0.5629
# Epoch 9/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.5386 - accuracy: 0.5616 - val_loss: 1.5936 - val_accuracy: 0.5627
# Epoch 10/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.5352 - accuracy: 0.5625 - val_loss: 1.5446 - val_accuracy: 0.5750
# Epoch 11/50
# 391/391 [==============================] - 13s 34ms/step - loss: 1.5253 - accuracy: 0.5650 - val_loss: 1.5965 - val_accuracy: 0.5635
# Epoch 12/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.5259 - accuracy: 0.5664 - val_loss: 1.5604 - val_accuracy: 0.5696
# Epoch 13/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.5109 - accuracy: 0.5704 - val_loss: 1.5618 - val_accuracy: 0.5658
# Epoch 14/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.5050 - accuracy: 0.5706 - val_loss: 1.5763 - val_accuracy: 0.5722
# Epoch 15/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.5026 - accuracy: 0.5694 - val_loss: 1.5590 - val_accuracy: 0.5753
# Epoch 16/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4957 - accuracy: 0.5732 - val_loss: 1.6234 - val_accuracy: 0.5566
# Epoch 17/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.4984 - accuracy: 0.5740 - val_loss: 1.6057 - val_accuracy: 0.5628
# Epoch 18/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.4919 - accuracy: 0.5759 - val_loss: 1.5555 - val_accuracy: 0.5706
# Epoch 19/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.4791 - accuracy: 0.5774 - val_loss: 1.5628 - val_accuracy: 0.5705
# Epoch 20/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4716 - accuracy: 0.5803 - val_loss: 1.6276 - val_accuracy: 0.5570
# Epoch 21/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4736 - accuracy: 0.5766 - val_loss: 1.5552 - val_accuracy: 0.5730
# Epoch 22/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4687 - accuracy: 0.5803 - val_loss: 1.5247 - val_accuracy: 0.5770
# Epoch 23/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.4586 - accuracy: 0.5828 - val_loss: 1.5522 - val_accuracy: 0.5675
# Epoch 24/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4512 - accuracy: 0.5839 - val_loss: 1.5271 - val_accuracy: 0.5776
# Epoch 25/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.4591 - accuracy: 0.5847 - val_loss: 1.5230 - val_accuracy: 0.5765
# Epoch 26/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.4631 - accuracy: 0.5782 - val_loss: 1.5475 - val_accuracy: 0.5671
# Epoch 27/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.4498 - accuracy: 0.5850 - val_loss: 1.5522 - val_accuracy: 0.5751
# Epoch 28/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.4355 - accuracy: 0.5880 - val_loss: 1.5650 - val_accuracy: 0.5695
# Epoch 29/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.4382 - accuracy: 0.5878 - val_loss: 1.5614 - val_accuracy: 0.5719
# Epoch 30/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.4294 - accuracy: 0.5880 - val_loss: 1.5425 - val_accuracy: 0.5753
# Epoch 31/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4180 - accuracy: 0.5925 - val_loss: 1.5397 - val_accuracy: 0.5767
# Epoch 32/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.4237 - accuracy: 0.5874 - val_loss: 1.5225 - val_accuracy: 0.5837
# Epoch 33/50
# 391/391 [==============================] - 13s 34ms/step - loss: 1.4123 - accuracy: 0.5948 - val_loss: 1.5410 - val_accuracy: 0.5806
# Epoch 34/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.4092 - accuracy: 0.5936 - val_loss: 1.5432 - val_accuracy: 0.5776
# Epoch 35/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.4125 - accuracy: 0.5933 - val_loss: 1.5339 - val_accuracy: 0.5799
# Epoch 36/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.4034 - accuracy: 0.5947 - val_loss: 1.5237 - val_accuracy: 0.5804
# Epoch 37/50
# 391/391 [==============================] - 13s 32ms/step - loss: 1.3979 - accuracy: 0.5949 - val_loss: 1.5134 - val_accuracy: 0.5836
# Epoch 38/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.3979 - accuracy: 0.5953 - val_loss: 1.5252 - val_accuracy: 0.5821
# Epoch 39/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3893 - accuracy: 0.5993 - val_loss: 1.5088 - val_accuracy: 0.5850
# Epoch 40/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3837 - accuracy: 0.6009 - val_loss: 1.5355 - val_accuracy: 0.5824
# Epoch 41/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3877 - accuracy: 0.6008 - val_loss: 1.5325 - val_accuracy: 0.5832
# Epoch 42/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3880 - accuracy: 0.5973 - val_loss: 1.5454 - val_accuracy: 0.5786
# Epoch 43/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3790 - accuracy: 0.6017 - val_loss: 1.5162 - val_accuracy: 0.5843
# Epoch 44/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3768 - accuracy: 0.6033 - val_loss: 1.5126 - val_accuracy: 0.5855
# Epoch 45/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3695 - accuracy: 0.6019 - val_loss: 1.5072 - val_accuracy: 0.5863
# Epoch 46/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.3721 - accuracy: 0.6024 - val_loss: 1.5241 - val_accuracy: 0.5823
# Epoch 47/50
# 391/391 [==============================] - 13s 33ms/step - loss: 1.3744 - accuracy: 0.6025 - val_loss: 1.4922 - val_accuracy: 0.5874
# Epoch 48/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3657 - accuracy: 0.6060 - val_loss: 1.5088 - val_accuracy: 0.5865
# Epoch 49/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3566 - accuracy: 0.6078 - val_loss: 1.5037 - val_accuracy: 0.5869
# Epoch 50/50
# 391/391 [==============================] - 12s 32ms/step - loss: 1.3574 - accuracy: 0.6074 - val_loss: 1.5093 - val_accuracy: 0.5906

# %%
model.save('Cifar100_CNN.h5')
