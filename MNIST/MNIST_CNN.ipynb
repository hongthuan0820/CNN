# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras import datasets
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, ZeroPadding2D
from keras.models import load_model

# %%
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train/=255
x_test/=255
y_train = np_utils.to_categorical(y_train,10)
y_test = np_utils.to_categorical(y_test,10)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same', input_shape=(28,28,1)))
model.add(Conv2D(32,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64,(3,3), activation = 'relu', kernel_initializer = 'he_uniform', padding = 'same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(32, activation = 'relu'))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)        320
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 3136)              0
#
#  dense_4 (Dense)             (None, 32)                100384
#
#  dense_5 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 128,778
# Trainable params: 128,778
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit(x_train,y_train,batch_size = 128, epochs = 10,verbose = 1, validation_data =(x_test,y_test))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 17s 10ms/step - loss: 0.3742 - accuracy: 0.8785 - val_loss: 0.0603 - val_accuracy: 0.9819
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0852 - accuracy: 0.9739 - val_loss: 0.0419 - val_accuracy: 0.9861
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0645 - accuracy: 0.9802 - val_loss: 0.0345 - val_accuracy: 0.9884
# Epoch 4/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0545 - accuracy: 0.9829 - val_loss: 0.0280 - val_accuracy: 0.9906
# Epoch 5/10
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0484 - accuracy: 0.9848 - val_loss: 0.0271 - val_accuracy: 0.9907
# Epoch 6/10
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0435 - accuracy: 0.9860 - val_loss: 0.0234 - val_accuracy: 0.9924
# Epoch 7/10
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0397 - accuracy: 0.9869 - val_loss: 0.0213 - val_accuracy: 0.9929
# Epoch 8/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0361 - accuracy: 0.9878 - val_loss: 0.0203 - val_accuracy: 0.9929
# Epoch 9/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0341 - accuracy: 0.9892 - val_loss: 0.0203 - val_accuracy: 0.9924
# Epoch 10/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0309 - accuracy: 0.9899 - val_loss: 0.0194 - val_accuracy: 0.9926

# %%
model.save('MNIST_CNN.h5')
